# %% [markdown]
# <a href="https://colab.research.google.com/github/aadilkhalifa/coursera-test/blob/master/Copy_of_DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 259 (delta 6), reused 7 (delta 2), pack-reused 242
# Receiving objects: 100% (259/259), 12.12 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2021-02-18 07:36:30--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.91.131
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.91.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  22.2MB/s    in 8.4s
#
# 2021-02-18 07:36:39 (19.6 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

import glob
images = glob.glob('/content/DenseDepth/examples' + '/*.png')
for i in images:
  img=cv2.imread(i)
  img=cv2.resize(img,(640,480))
  cv2.imwrite(i,img)

# %%
# !cd DenseDepth; python test.py
# Out:
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (13) images of size (480, 640, 3).
# (13, 240, 320, 1)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# (240, 320)
# <Figure size 1000x500 with 1 Axes>

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
# !cd DenseDepth/PyTorch; python test_pytorch.py
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
# !pwd
# Out:
# /content

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2

# img1=cv2.imread('/content/DenseDepth/examples/119_image.png')
# img2=cv2.imread('/content/DenseDepth/examples/screenshot.png')

# img2=cv2.resize(img2,(640,480))
# cv2.imwrite('/content/DenseDepth/examples/screenshot.png',img2)

# cv2.imread('/content/DenseDepth/examples/screenshot.png').shape
# Out:
# (480, 640, 3)

# %%
cv2.imread('/content/DenseDepth/examples/screenshot.png').shape
# Out:
# (1080, 1920, 3)

# %%
img1.shape[:2]
# Out:
# (480, 640)

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2
